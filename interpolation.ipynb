# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: 2.1 + 0.8*(x-1)+1.0833*(x-1)*(x-1.5)-0.98473*(x-1)*(x-1.5)*(x-1.8)

t = [1.0, 1.5, 1.8, 2.1]
e = [2.1, 2.5, 3.0, 3.5]

x = np.linspace(0, 3, 200)
y = f(x)

plt.plot(x, y)
plt.plot(t, e, 'o')
